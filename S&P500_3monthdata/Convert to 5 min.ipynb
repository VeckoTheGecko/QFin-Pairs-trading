# %%
import os
import pandas as pd
import numpy as np

DATA_FOLDER = "ticker_breakdown"
FILE_LST = [os.path.join(DATA_FOLDER, file_name) for file_name in os.listdir(DATA_FOLDER)]

class Stock:
    def __init__(self, file_name, data_folder):
        self.file_name = file_name
        self.file_path = os.path.join(data_folder, file_name)
        self.name = file_name.split(".")[0]
    
    def convert_to_5(self):
        def get_data(self):
            return pd.read_csv(self.file_path)

        data = get_data()

        
        self.data_frame = self.file_name
# Out:
# ['ticker_breakdown\\A.csv', 'ticker_breakdown\\AAL.csv', 'ticker_breakdown\\AAP.csv', 'ticker_breakdown\\AAPL.csv', 'ticker_breakdown\\ABBV.csv', 'ticker_breakdown\\ABC.csv', 'ticker_breakdown\\ABMD.csv', 'ticker_breakdown\\ABT.csv', 'ticker_breakdown\\ACN.csv', 'ticker_breakdown\\ADBE.csv', 'ticker_breakdown\\ADI.csv', 'ticker_breakdown\\ADM.csv', 'ticker_breakdown\\ADP.csv', 'ticker_breakdown\\ADSK.csv', 'ticker_breakdown\\AEE.csv', 'ticker_breakdown\\AEP.csv', 'ticker_breakdown\\AES.csv', 'ticker_breakdown\\AFL.csv', 'ticker_breakdown\\AIG.csv', 'ticker_breakdown\\AIZ.csv', 'ticker_breakdown\\AJG.csv', 'ticker_breakdown\\AKAM.csv', 'ticker_breakdown\\ALB.csv', 'ticker_breakdown\\ALGN.csv', 'ticker_breakdown\\ALK.csv', 'ticker_breakdown\\ALL.csv', 'ticker_breakdown\\ALLE.csv', 'ticker_breakdown\\ALXN.csv', 'ticker_breakdown\\AMAT.csv', 'ticker_breakdown\\AMCR.csv', 'ticker_breakdown\\AMD.csv', 'ticker_breakdown\\AME.csv', 'ticker_breakdown\\AMGN.csv', 'ticker_breakdown\\AMP.csv', '
# ...

# %%
df = pd.read_csv(os.path.join)
